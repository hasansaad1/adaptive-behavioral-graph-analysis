# %% [markdown]
# # ABRG reproduce index
#
# Per-run notebooks live beside frozen outputs under `abrg/output/`. Validate one run:
#
# ```bash
# cd REPO_ROOT
# .venv/bin/python -m abrg.validate_reproduce --run-dir abrg/output/<run_id>
# ```
#
# Status table: `abrg/output/REPRODUCE_STATUS.md`
#
# | run_id | kind | validate |
# |---|---|---|
# | `androct_2017/arm_a_n1` | androct_auc | ok |
# | `androct_2017/arm_b_n8` | androct_auc | ok |
# | `androct_2017/run2` | androct_auc | ok |
# | `androct_2017/run3` | androct_auc | ok |
# | `androct_2017/run3_5` | androct_auc | ok |
# | `androct_2017/run4` | androct_auc | ok |
# | `androct_2017/run5` | androct_auc | ok |
# | `androct_2017/run8` | androct_auc | ok |
# | `androct_2017/run6/part1_ablation` | androct_auc | ok |
# | `androct_2017/run6/part2_geometry` | androct_auc | ok |
# | `androct_2017/run6/part3_armB` | androct_auc | ok |
# | `androct_2017/run6/centroid_node_ablation` | androct_auc | ok |
# | `androct_2017/run6/oneclass_baselines` | androct_auc | ok |
# | `androct_2017/run6/ipc_scalar_probes` | androct_auc | ok |
# | `androct_2017/run6/whiten_h8_a02` | androct_auc | ok |
# | `norm_ab_v2` | ratio | ok |
# | `norm_ab_v2_weighted` | ratio | ok |
# | `negative_control_v2` | negative_control | ok |
# | `negative_control_v2_weighted` | negative_control | ok |
# | `exp_adaptive_ratio/w15_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w25_h64_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w30_e600_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w30_h128_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w30_h32_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w30_h64_e450_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w30_h64_lr005_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w30_h64_lr02_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w30_h64_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w30_h96_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w30_unweighted` | ratio | ok |
# | `exp_adaptive_ratio/w35_h48_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w35_h64_e320_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w35_h64_unweighted` | ratio | ok |
# | `exp_adaptive_ratio/w35_h64_wd1e4_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w35_h64_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w40_h64_weighted` | ratio | ok |
# | `exp_adaptive_ratio/w45_weighted` | ratio | ok |
# | `exp_drop_inactive/w35_h64_drop7` | ratio | ok |
# | `exp_epochs/e600_weighted` | ratio | ok |
# | `exp_near_origin/delta7_weighted` | ratio | ok |
# | `exp_near_origin/e280_weighted` | ratio | ok |
# | `exp_near_origin/edge_wrec_weighted` | ratio | ok |
# | `exp_near_origin/finalsnap_weighted` | ratio | ok |
# | `exp_near_origin/k3_weighted` | ratio | ok |
# | `exp_near_origin/k7_weighted` | ratio | ok |
# | `exp_near_origin/lam005_weighted` | ratio | ok |
# | `exp_near_origin/w34_h64_weighted` | ratio | ok |
# | `exp_near_origin/w36_h64_weighted` | ratio | ok |
# | `exp_near_origin/wd1e5_weighted` | ratio | ok |
# | `exp_window_sec/w120_weighted` | ratio | fail |
# | `exp_window_sec/w30_weighted` | ratio | ok |
# | `desc_seed` | desc_seed | ok |

# %%
from pathlib import Path
REPO_ROOT = Path.cwd().resolve()
if not (REPO_ROOT / "abrg").is_dir():
    REPO_ROOT = REPO_ROOT.parent
runs = [
  "androct_2017/arm_a_n1",
  "androct_2017/arm_b_n8",
  "androct_2017/run2",
  "androct_2017/run3",
  "androct_2017/run3_5",
  "androct_2017/run4",
  "androct_2017/run5",
  "androct_2017/run8",
  "androct_2017/run6/part1_ablation",
  "androct_2017/run6/part2_geometry",
  "androct_2017/run6/part3_armB",
  "androct_2017/run6/centroid_node_ablation",
  "androct_2017/run6/oneclass_baselines",
  "androct_2017/run6/ipc_scalar_probes",
  "androct_2017/run6/whiten_h8_a02",
  "norm_ab_v2",
  "norm_ab_v2_weighted",
  "negative_control_v2",
  "negative_control_v2_weighted",
  "exp_adaptive_ratio/w15_weighted",
  "exp_adaptive_ratio/w25_h64_weighted",
  "exp_adaptive_ratio/w30_e600_weighted",
  "exp_adaptive_ratio/w30_h128_weighted",
  "exp_adaptive_ratio/w30_h32_weighted",
  "exp_adaptive_ratio/w30_h64_e450_weighted",
  "exp_adaptive_ratio/w30_h64_lr005_weighted",
  "exp_adaptive_ratio/w30_h64_lr02_weighted",
  "exp_adaptive_ratio/w30_h64_weighted",
  "exp_adaptive_ratio/w30_h96_weighted",
  "exp_adaptive_ratio/w30_unweighted",
  "exp_adaptive_ratio/w35_h48_weighted",
  "exp_adaptive_ratio/w35_h64_e320_weighted",
  "exp_adaptive_ratio/w35_h64_unweighted",
  "exp_adaptive_ratio/w35_h64_wd1e4_weighted",
  "exp_adaptive_ratio/w35_h64_weighted",
  "exp_adaptive_ratio/w40_h64_weighted",
  "exp_adaptive_ratio/w45_weighted",
  "exp_drop_inactive/w35_h64_drop7",
  "exp_epochs/e600_weighted",
  "exp_near_origin/delta7_weighted",
  "exp_near_origin/e280_weighted",
  "exp_near_origin/edge_wrec_weighted",
  "exp_near_origin/finalsnap_weighted",
  "exp_near_origin/k3_weighted",
  "exp_near_origin/k7_weighted",
  "exp_near_origin/lam005_weighted",
  "exp_near_origin/w34_h64_weighted",
  "exp_near_origin/w36_h64_weighted",
  "exp_near_origin/wd1e5_weighted",
  "exp_window_sec/w120_weighted",
  "exp_window_sec/w30_weighted",
  "desc_seed"
]
for run_id in runs:
    nb = REPO_ROOT / "abrg" / "output" / run_id / "reproduce.ipynb"
    print(run_id, "OK" if nb.is_file() else "MISSING", nb)
